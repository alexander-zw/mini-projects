# %% [markdown]
# # Using Binomial to Estimate Poisson

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Visualization for my section

# %%
from scipy.special import comb
from scipy import math
from math import factorial

# %%
def binom_prob(n, p, k):
    return comb(n, k) * p**k * (1 - p)**(n - k)

def poisson_prob(lamb, k):
    return lamb**k / factorial(k) * np.e**(-lamb)

# %%
ns = [3, 10, 30, 100, 300]
limit = 7

plt.figure()
for n in ns:
    p = 2.5 / n
    ks = np.arange(0, n)[:limit]
    probs = [binom_prob(n, p, k) for k in ks][:limit]

    plt.bar(ks, probs, align='center', alpha=0.3)
    print('.', end='')

plt.xticks(ks, ks)
plt.ylabel('probability')
plt.title('binomial distribution')
plt.legend(ns)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# .....

# %%
ns = [3, 10, 30, 100, 300]
limit = 7
lamb = 2.5

plt.figure()
for n in ns:
    p = lamb / n
    ks = np.arange(0, n)[:limit]
    probs = np.array([binom_prob(n, p, k) for k in ks])[:limit]

    plt.plot(ks, probs)
    print('.', end='')

ks = np.arange(0, limit)
probs = np.array([poisson_prob(lamb, k) for k in ks])

plt.plot(ks, probs)
print('.', end='')
    
plt.xticks(ks, ks)
plt.xlabel('$k$')
plt.ylabel('$P(X=k)$')
plt.title('binomial distribution vs poisson')
plt.legend(ns + ['$\infty$'])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# ......

# %%
print(poisson_prob(1, 0), 1/np.e)
# Out:
# 0.36787944117144233 0.36787944117144233

# %%
fig, ax = plt.subplots()
ax.bar(0.5, [1,2], 1, label='pre')
ax.bar(1.5, [2,3], 1, label='post')

ax.bar(3.5, [1,2], 1, label='pre')
ax.bar(4.5, [2,3], 1, label='post')

plt.ylabel('probability')
plt.title('binomial distribution')
plt.legend(['pre', 'post'])

plt.show()
